# %% [markdown]
# # CCB Data Collection and Preprocessing
#
# ## Objectives
#
# 1. Import the EUR/USD Cross-Currency Basis data.
# 2. Explore and plot the series (1M, 3M, 12M tenors).
# 3. Test for stationarity using the ADF test.
# 4. Apply transformations if required.
# 5. Export the processed CCB dataset.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# ## 1. Import Datasets
#
# Due to the transition from LIBOR to the Secured Overnight Financing Rate (SOFR), the only data I was able to export from Bloomberg regarding the EUR/USD cross-currency basis (CCB) begins in February 2021.
#
# The following imported datasets represent the 3M and 12M (1Y) EURUSD Basis Swap (ESTRON vs SOFRRATE) and are extracted from Bloomberg Terminal.

# %%
ccb3m = pd.read_csv("../data/raw/EURUSD_Basis_Swap_ESTRONvsSOFRRATE_3M.csv", parse_dates=True, index_col=0)

ccb12m = pd.read_csv("../data/raw/EURUSD_Basis_Swap_ESTRONvsSOFRRATE_12M.csv", parse_dates=True, index_col=0)

# %% [markdown]
# ## 2. Initial Inspection

# %%
print("CCB 3M DataFrame Info:")
print(ccb3m.head())

print("\nCCB 12M DataFrame Info:")
print(ccb12m.head())
